# %%
from modulos import eda
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Bacia do Rio Negro - Rio Curicuriari

# %% [markdown]
# ### Estações

# %% [markdown]
# Fonte: https://www.snirh.gov.br/hidroweb/serieshistoricas
#
# Bacia: 1 - RIO AMAZONAS\
# SubBacia: 14 - RIO SOLIMÕES,NEGRO,BRANCO,...\
# Rio: Rio Curicuriari
#
# 1. 14325000
# Nome: Tumbira\
# Estado: Amazonas\
# Município: São Gabriel da Cachoeira\
# Responsável: ANA\
# Operadora: SGB-PCRM\
# Latitude: -0.3444\
# Longitude: -67.5358
#
# 2. 14350000
# Nome: Jusante da Cachoeira do Caju\
# Estado: Amazonas\
# Município: São Gabriel da Cachoeira\
# Responsável: ANA\
# Operadora: SGB-PCRM\
# Latitude: -0.2461\
# Longitude: -67.0092

# %%
arquivos = [
    'dados_diarios_estacao_14325000.csv',
    'dados_diarios_estacao_14350000.csv'
]

dados = eda.data_processing('Cotas extraidas', '2000-01-01', '2024-12-31', arquivos)
dados
# Out:
#             14325000  14350000
# Data
# 2000-01-01     735.0    1193.0
# 2000-01-02     713.0    1186.0
# 2000-01-03     700.0    1174.0
# 2000-01-04     700.0    1160.0
# 2000-01-05     711.0    1142.0
# ...              ...       ...
# 2024-12-27    1100.0    1495.0
# 2024-12-28    1140.0    1509.0
# 2024-12-29    1181.0    1523.0
# 2024-12-30    1206.0    1547.0
# 2024-12-31    1220.0    1572.0
#
# [9132 rows x 2 columns]

# %% [markdown]
# ### Gráficos

# %%
eda.seasonal_plot(dados, (12, 4))

# %%
eda.annual_plot(dados, (12, 8))
