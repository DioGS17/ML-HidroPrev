# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
gdf = gpd.read_file('bacias_nivel_3/bacias_nivel_3.shp')

# %%
rio_negro = gdf[gdf['nome_bacia'] == 'Bacia do Rio Negro']
rio_negro
# Out:
#     id cod_otto  niv_otto          nome_bacia curso_prin  \
# 15  16      648         3  Bacia do Rio Negro  Rio Negro
#
#                                           princ_aflu  \
# 15  Rio Demini, Rio Branco, Rio Jauaperi, Rio Uaupés
#
#                                            sub_bacias             suprabacia  \
# 15  Bacia do Rio Jauaperi, Bacia do Rio Uaupés, Ba...  Bacia do Rio Amazonas
#
#     ordem_hstr  ordem_grav  ...  dispohidri  dem_total  dem_humurb  \
# 15           9           2  ...      8973.8    15.3032     6.44997
#
#     dem_humrur  dem_ind_tr  dem_minera  dem_termel  dem_animal  dem_irriga  \
# 15     0.27342    0.838015    0.051946     3.46801    0.535121     3.68674
#
#                                              geometry
# 15  POLYGON ((-63.60102 -2.73708, -63.60187 -2.737...
#
# [1 rows x 32 columns]

# %%
rio_negro.plot('area_total', facecolor='blue', edgecolor='black')
# Out:
# <Axes: >
