# %%
from modulos import eda
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Bacia do Rio Negro - Rio Branco

# %% [markdown]
# ### Estações

# %% [markdown]
# Fonte: https://www.snirh.gov.br/hidroweb/serieshistoricas
#
# Bacia: 1 - RIO AMAZONAS\
# SubBacia: 14 - RIO SOLIMÕES,NEGRO,BRANCO,...\
# Rio: Rio Branco
#
# 1. 14620000\
# Nome: Boa Vista\
# Estado: Roraima\
# Município: Boa Vista\
# Responsável: ANA\
# Operadora: SGB-PCRM\
# Latitude: 2.2867\
# Longitude: -60.6561
#
# 2. 14710000\
# Nome: Caracaraí\
# Estado: Roraima\
# Município: Caracaraí\
# Responsável: ANA\
# Operadora: SGB-PCRM\
# Latitude: 1.8214\
# Longitude: -61.1236
#
# 3. 14790000\
# Nome: Santa Maria do Boiaçu\
# Estado: Roraima\
# Município: Rorainopólis\
# Responsável: ANA\
# Operadora: SGB-PCRM\
# Latitude: -0.5053\
# Longitude: -61.7864

# %%
arquivos = [
    'dados_diarios_estacao_14620000.csv',
    'dados_diarios_estacao_14710000.csv',
    'dados_diarios_estacao_14790000.csv'
]
dados = eda.data_processing('Cotas extraidas', '1985-01-01', '2023-12-31', arquivos)
dados
# Out:
#             14620000  14710000  14790000
# Data
# 1985-01-01     285.0     281.0     509.0
# 1985-01-02     309.0     285.0     503.0
# 1985-01-03     310.0     290.0     498.0
# 1985-01-04     260.0     293.0     504.0
# 1985-01-05     259.0     280.0     510.0
# ...              ...       ...       ...
# 2023-12-27      83.0     126.0     340.0
# 2023-12-28      84.0     131.0     339.0
# 2023-12-29      78.0     137.0     345.0
# 2023-12-30      76.0     135.0     354.0
# 2023-12-31      79.0     131.0     361.0
#
# [14244 rows x 3 columns]

# %% [markdown]
# ### Gráficos

# %%
eda.seasonal_plot(dados, (12, 8))

# %%
eda.annual_plot(dados, (12, 8))
