# %%
from modulos import eda
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Bacia do Rio Negro - Rio Uaupés

# %% [markdown]
# ### Estações

# %% [markdown]
# Fonte: https://www.snirh.gov.br/hidroweb/serieshistoricas
#
# Bacia: 1 - Rio Negro\
# SubBacia: 14 - RIO SOLIMÕES,NEGRO,BRANCO,...\
# Rio: Rio Vaupés\Uaupés
#
# 1. 14260000\
# Nome: Uaraçu\
# Estado: Amazonas\
# Município: São Gabriel da Cachoeira\
# Responsável: ANA\
# Operadora: SGB-PCRM\
# Latitude: 0.4769\
# Longitude: -69.1281
#
# 2. 14280001\
# Nome: Taraquá\
# Estado: Amazonas\
# Município: São Gabriel da Cachoeira\
# Responsável: ANA\
# Operadora: SGB-PCRM\
# Latitude: 0.1303\
# Longitude: -68.5386

# %%
arquivos = [
    'dados_diarios_estacao_14260000.csv',
    'dados_diarios_estacao_14280001.csv'
]

dados = eda.data_processing('Cotas extraidas', '1985-01-01', '2024-12-31', arquivos)
dados
# Out:
#             14260000  14280001
# Data
# 1985-01-01     747.0    1319.0
# 1985-01-02     738.0    1317.0
# 1985-01-03     725.0    1311.0
# 1985-01-04     710.0    1301.0
# 1985-01-05     685.0    1286.0
# ...              ...       ...
# 2024-12-27     624.0    1150.0
# 2024-12-28     653.0    1157.0
# 2024-12-29     676.0    1178.0
# 2024-12-30     691.0    1200.0
# 2024-12-31     689.0    1206.0
#
# [14610 rows x 2 columns]

# %%
eda.seasonal_plot(dados, (12, 4))

# %%
eda.annual_plot(dados, (12, 4))
