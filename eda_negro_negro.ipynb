# %%
# Bibliotecas
import eda
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Bacia do Rio Negro - Rio Negro

# %% [markdown]
# ### Estações

# %% [markdown]
# Bacia: 1 - RIO AMAZONAS\
# SubBacia: 14 - RIO SOLIMÕES,NEGRO,BRANCO...\
# Rio: RIO NEGRO
#
# 1. 14110000\
# Nome: Cucuí\
# Estado: Amazonas\
# Município: São Gabriel da Cachoeira\
# Responsável: ANA\
# Operadora: SGB-CPRM\
# Latiude: 1.2153°\
# Longitude: -66.8525°
#
# 2. 14250000\
# Nome: São Felipe\
# Estado: Amazonas\
# Município: São Gabriel da Cachoeira\
# Responsável: ANA\
# Operadora: SGB-CPRM\
# Latiude: 0.3717°\
# Longitude: -67.3128°
#
# 3. 14320001\
# Nome: São Gabriel da Cachoeira\
# Estado: Amazonas\
# Município: São Gabriel da Cachoeira\
# Responsável: ANA\
# Operadora: SGB-CPRM\
# Latiude: -O.1367°\
# Longitude: -67.0856°
#
# 4. 14330000\
# Nome: Curicuriari\
# Estado: Amazonas\
# Município: São Gabriel da Cachoeira\
# Responsável: ANA\
# Operadora: SGB-CPRM\
# Latiude: -0,2006°\
# Longitude: -66,8022°
#
# 5. 14400000\
# Nome: Tapuruquara\
# Estado: Amazonas\
# Município: Santa Izabel do Rio Negro\
# Responsável: ANA\
# Operadora: SGB-CPRM\
# Latitude: -0.4203°\
# Longitude: -65.0153°
#
# 6. 14420000\
# Nome: Serrinha\
# Estado: Amazonas\
# Município: Santa Izabel do Rio Negro\
# Responsável: ANA\
# Operadora: SGB-CPRM\
# Latitude: -0.4819°\
# Longitude: -64.8289°
#
# 7. 14480002\
# Nome: Barcelos\
# Estado: Amazonas\
# Município: Barcelos\
# Responsável: ANA\
# Operadora: SGB-CPRM\
# Latitude: -0.9658°\
# Longitude: -62.9311°
#
# 8. 14840000\
# Nome: Moura\
# Estado: Amazonas\
# Município: Barcelos\
# Responsável: ANA\
# Operadora: SGB-CPRM\
# Latitude: -1.4567°\
# Longitude: -61.634°
#
# 9. 14900050\
# Nome: Novo Airão\
# Estado: Amazonas\
# Município: Novo Airão\
# Responsável: ANA\
# Operadora: SGB-CPRM\
# Latitude: -2.625°\
# Longitude: -60.9364°
#
# 10. 14911000\
# Nome: Tatu Paricatuba\
# Estado: Amazonas\
# Município: Manaus\
# Responsável: ANA\
# Operadora: SGB-CPRM\
# Latitude: -3.0594°\
# Longitude: -60.2653°
#
# 11. 14990000\
# Nome: Manaus\
# Estado: Amazonas\
# Município: Manaus\
# Responsável: ANA\
# Operadora: SGB-CPRM\
# Latitude: -3.1383°\
# Longitude: -60.0272°

# %% [markdown]
# ### Tratando os dados

# %%
# Abrindo os arquivos CSV
path = 'Cotas extraidas'
arquivos = [
    'dados_diarios_estacao_14110000.csv',
    'dados_diarios_estacao_14250000.csv',
    'dados_diarios_estacao_14320001.csv',
    'dados_diarios_estacao_14330000.csv',
    'dados_diarios_estacao_14400000.csv',
    'dados_diarios_estacao_14480002.csv',
    'dados_diarios_estacao_14840000.csv',
    'dados_diarios_estacao_14900050.csv',
    'dados_diarios_estacao_14911000.csv',
    'dados_diarios_estacao_14990000.csv'
]

dados = eda.data_processing(path, '2015-01-01', '2023-12-31', arquivos)
dados
# Out:
#             14110000  14250000  14320001  14330000  14400000  14480002  \
# Data
# 2015-01-01    1480.0     733.0     736.0     957.0     329.0     298.0
# 2015-01-02    1472.0     727.0     736.0     959.0     333.0     299.0
# 2015-01-03    1458.0     716.0     730.0     955.0     337.0     301.0
# 2015-01-04    1447.0     707.0     717.0     948.0     339.0     304.0
# 2015-01-05    1429.0     698.0     706.0     941.0     337.0     307.0
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-27    1480.0     651.0     697.0     846.0     361.0     325.0
# 2023-12-28    1485.0     662.0     695.0     841.0     357.0     329.0
# 2023-12-29    1492.0     673.0     701.0     847.0     356.0     331.0
# 2023-12-30    1497.0     684.0     709.0     870.0     357.0     333.0
# 2023-12-31    1495.0     691.0     725.0     893.0     361.0     334.0
#
#             14840000  14900050  14911000  14990000
# Data
# 2015-01-01     609.0    1077.0    2190.0    2171.0
# 2015-01-02     609.0    1079.0    2188.0    2174.0
# 2015-01-03     610.0    1081.0    2191.0    2175.0
# 2015-01-04     612.0    1083.0    2194.0    2177.0
# 2015-01-05     614.0    1087.0    2198.0    2179.0
# ...              ...       ...       ...       ...
# 2023-12-27     413.0     741.0    1840.0    1807.0
# 2023-12-28     421.0     749.0    1854.0    1822.0
# 2023-12-29     427.0     760.0    1866.0    1834.0
# 2023-12-30     436.0     776.0    1881.0    1849.0
# 2023-12-31     446.0     789.0    1892.0    1864.0
#
# [3287 rows x 10 columns]

# %% [markdown]
# ### Gráficos

# %%
# Variação sazonal

eda.seasonal_plot(dados, (12, 24))

# %% [markdown]
# Analisando os gráficos sazonais de cada estação, é possível observar o mesmo padrão, ou semelhante, em todas as estações, com o rio enchendo no ínicio do primeiro semestre, atingindo um pico entre julho e agosto, e depois secando. Como as estações seguem o mesmo fluxo, então é normal que haja esse padrão.

# %%
# Variação anual

eda.annual_plot(dados, (18, 20))

# %%
eda.cross_corr(dados, '14990000')
# Out:
# Estação 14110000: Melhor lag = 24; Correlação = 0.5350
# Estação 14250000: Melhor lag = 24; Correlação = 0.6447
# Estação 14320001: Melhor lag = 25; Correlação = 0.6167
# Estação 14330000: Melhor lag = 25; Correlação = 0.6261
# Estação 14400000: Melhor lag = 21; Correlação = 0.6426
# Estação 14480002: Melhor lag = 15; Correlação = 0.7456
# Estação 14840000: Melhor lag = 5; Correlação = 0.8399
# Estação 14900050: Melhor lag = 1; Correlação = 0.9587
# Estação 14911000: Melhor lag = 1; Correlação = 0.9660
