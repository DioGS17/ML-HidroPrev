# %%
import eda
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Bacia do Rio Negro - Rio Tiquié

# %%
arquivos = [
    'dados_diarios_estacao_14300000.csv',
    'dados_diarios_estacao_14310000.csv'
]
dados = eda.data_processing('Cotas extraidas', '1985-01-01', '2023-12-31', arquivos)
dados
# Out:
#             14300000  14310000
# Data
# 1985-01-01     842.0     973.0
# 1985-01-02     822.0     970.0
# 1985-01-03     798.0     958.0
# 1985-01-04     751.0     939.0
# 1985-01-05     709.0     908.0
# ...              ...       ...
# 2023-12-27     552.0     594.0
# 2023-12-28     575.0     561.0
# 2023-12-29     687.0     578.0
# 2023-12-30     714.0     630.0
# 2023-12-31     698.0     652.0
#
# [14244 rows x 2 columns]

# %%
eda.seasonal_plot(dados, (12, 4))

# %%
eda.annual_plot(dados, (16, 8))
