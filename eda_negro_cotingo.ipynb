# %%
from modulos import eda
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Bacia do Rio Negro - Rio Cotingo

# %% [markdown]
# ### Estações

# %% [markdown]
# Fonte: https://www.snirh.gov.br/hidroweb/serieshistoricas
#
# Bacia: 1 - RIO AMAZONAS\
# SubBacia: 14 - RIO SOLIMÕES,NEGRO,BRANCO,...\
# Rio: Rio Cotingo
#
# 1. 14540000\
# Nome: Fazenda Bandeira Branca\
# Estado: Roraima\
# Município: Uiramutã\
# Responsável: ANA\
# Operadora: SGB-PCRM\
# Latitude: 4.6306\
# Longitude: -60.4706
#
# 2. 14550000\
# Nome: Maloca do Contão\
# Estado: Roraima\
# Município: Pacaraima\
# Responsável: ANA\
# Operadora: SGB-PCRM\
# Latitude: 4.1675\
# Longitude: -60.5289

# %% [markdown]
# ### Gráficos

# %%
arquivos = [
    'dados_diarios_estacao_14540000.csv',
    'dados_diarios_estacao_14550000.csv'
]

dados = eda.data_processing('Cotas extraidas', '1985-01-01', '2024-12-31', arquivos)
dados
# Out:
#             14540000  14550000
# Data
# 1985-01-01     178.0     204.0
# 1985-01-02     166.0     186.0
# 1985-01-03     168.0     178.0
# 1985-01-04     169.0     178.0
# 1985-01-05     165.0     177.0
# ...              ...       ...
# 2024-12-27     142.0     150.0
# 2024-12-28     134.0     141.0
# 2024-12-29     132.0     144.0
# 2024-12-30     139.0     138.0
# 2024-12-31     148.0     150.0
#
# [14610 rows x 2 columns]

# %%
eda.seasonal_plot(dados, (12, 4))

# %%
eda.annual_plot(dados, (12, 8))
